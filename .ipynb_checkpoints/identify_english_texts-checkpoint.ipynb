# %%
#load the libraries
import json
import bz2
import pandas as pd
import orjson

#this function calculates relative frequencies
def rel_freq(x, name):
    #filter out None values
    valid_languages = [value for value in x if value is not None]

    #check if there are any valid languages, skip if there isn't
    if len(valid_languages) == 0:
        print(f"No valid language data found in {name}, skipping...")
        return
    
    #count the number of English pages
    en_count = sum(1 for value in valid_languages if value == 'en')
    
    #calculate the percentage of English pages
    if en_count / len(valid_languages) > 0.70:
        try:
            with open("engtexts.txt", "a") as myfile:
                myfile.write(name[34:] + "\n")
        except IOError as e:
            print(f"Error writing to engtexts.txt: {e}")

#function to process a single file
def process_file(name):
    try:
        #read in the compressed json
        with bz2.BZ2File(name, 'rb') as input_file:
            #read and decode
            input_file_content = input_file.read()
            json_input = input_file_content.decode('utf-8')
            
            #load the JSON
            data = orjson.loads(json_input)

            #extract the 'features' field from the JSON
            features = data.get('features', {})

            #check if pages exists and its a list
            if 'pages' in features and isinstance(features['pages'], list):
                #if both apply, create calculated languages, which gets the calculated languages
                calculated_languages = [
                    page.get('calculatedLanguage')
                    for page in features['pages']
                    if page.get('calculatedLanguage') is not None
                ]
                
                #call rel_freq to check if more than 70% of the text is in English
                rel_freq(calculated_languages, name)
    except Exception as e:
        print(f"Error processing {name}: {e}")

#pull in the list of filenames + paths
file_path = 'file_listing.txt'

#open it
with open(file_path, 'r') as file:
    #readlines
    path = file.read().splitlines()

#load all the ids we've already confirmed as being written in english
english_texts = 'engtexts.txt'

#open
with open(english_texts, 'r') as file:
    
    #read lines
    english_texts = file.read().splitlines()

#find the position of the last english_text in the list of paths
index = path.index(english_texts[-1])

#remove everything before this point from the list of paths
path = path[index:len(path)]

#add the actual folder locations to the start of each id
prefix = '../../Volumes/My Passport for Mac/'

#add the prefix
paths = [prefix + filename for filename in path]

#create empty variable calculated languages
calculated_languages = []

#for every name of jsons we have yet to load
for name in paths:
    calculated_languages = [] 
    
    #load zip file
    with bz2.BZ2File(name) as input_file:
        input_file_content = input_file.read()
        json_input = input_file_content.decode('utf-8')
        data = orjson.loads(json_input)

        #load the features
        features = data.get('features', {})
        if 'pages' in features and isinstance(features['pages'], list):
            for page in features['pages']:
                calculated_language = page.get('calculatedLanguage')
                if calculated_language:
                    calculated_languages.append(calculated_language)
                    
    #call relative frequency calculation for current file
    rel_freq(calculated_languages, name)
# Out:
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8071/wu.89105874911.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8072/wu.89105874929.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8073/wu.89105874531.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8074/wu.89105874945.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8076/wu.89105874267.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8077/wu.89105874275.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8077/wu.89105874473.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8078/wu.89105874580.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8078/wu.89105874689.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8080/wu.89101583805.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8080/wu.89101584605.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8082/wu.89107584724.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8083/wu.89101585032.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8084/wu.89100389949.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8088/wu.89102886983.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8090/wu.89007191000.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8090/wu.89104392907.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8091/wu.89104397914.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8092/wu.89104396221.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8096/wu.89104395967.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8098/wu.89101598985.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8098/wu.89104397880.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8099/wu.89101598597.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8105/wu.89017909052.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8113/wu.89011410032.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8118/wu.89119110880.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8120/wu.89119428506.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8122/wu.89119925626.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8127/wu.89119428472.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8128/wu.89119428480.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8132/wu.89012232526.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8132/wu.89018037325.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8135/wu.89117430157.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8142/wu.89018049528.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8177/wu.89017470675.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8198/wu.89015792583.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8199/wu.89013399894.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8312/wu.89030517221.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8318/wu.89031115785.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8330/wu.89030534507.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8335/wu.89030533855.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8366/wu.89034961466.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8380/wu.89031180003.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8382/wu.89034683623.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8422/wu.89044523728.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8435/wu.89042438358.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8448/wu.89044443984.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8472/wu.89046373528.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8473/wu.89041977430.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8479/wu.89049671191.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8483/wu.89047587530.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8487/wu.89046283073.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8498/wu.89042395582.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8521/wu.89053128518.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8539/wu.89058933094.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8540/wu.89057849101.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8542/wu.89057546624.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8544/wu.89057849945.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8560/wu.89055762405.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8560/wu.89056460603.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8560/wu.89057466807.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8561/wu.89056760416.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8561/wu.89059467811.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8565/wu.89056461452.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8566/wu.89056460561.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8573/wu.89056571235.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8576/wu.89058771064.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8579/wu.89055278394.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8579/wu.89056571193.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8588/wu.89055285688.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8594/wu.89057190241.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8596/wu.89056898166.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8599/wu.89058595596.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8600/wu.89066400300.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8601/wu.89060708419.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8607/wu.89067607671.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8608/wu.89067607085.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8611/wu.89061211819.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8612/wu.89069916427.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8621/wu.89060520111.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8626/wu.89063322861.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8626/wu.89066025560.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8632/wu.89063236327.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8634/wu.89066432840.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8636/wu.89063235667.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8651/wu.89061755914.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8654/wu.89062959846.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8658/wu.89061755880.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8665/wu.89062161856.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8669/wu.89067361493.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8675/wu.89061178950.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8682/wu.89060486628.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8683/wu.89069285732.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8693/wu.89064399033.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8702/wu.89075106526.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8715/wu.89073116550.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8717/wu.89073114175.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8718/wu.89073116485.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8723/wu.89074127333.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8731/wu.89072633316.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8743/wu.89070347836.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8743/wu.89075848838.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8745/wu.89073140253.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8746/wu.89070344064.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8748/wu.89078249984.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8749/wu.89073147290.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8750/wu.89070358502.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8750/wu.89074655507.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8752/wu.89078557121.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8753/wu.89070358536.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8753/wu.89071559330.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8756/wu.89071559363.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8777/wu.89076275171.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8778/wu.89077072387.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8781/wu.89072380611.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8783/wu.89079889937.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8787/wu.89077189678.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8804/wu.89082502345.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8805/wu.89085202752.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8815/wu.89081311052.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8822/wu.89083224428.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8836/wu.89086034766.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8845/wu.89086045051.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8848/wu.89081040784.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8863/wu.89082966334.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8869/wu.89080563497.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8876/wu.89089873566.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8886/wu.89086981164.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8896/wu.89086890266.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8900/wu.89095208708.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8909/wu.89099406290.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8910/wu.89091416602.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8912/wu.89098810526.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8932/wu.89096035225.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8934/wu.89095834743.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8936/wu.89094234366.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8939/wu.89098834591.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8939/wu.89098934391.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8944/wu.89092449149.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8947/wu.89098944879.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8949/wu.89096049598.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8956/wu.89094550761.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8961/wu.89095766010.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8966/wu.89099869760.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8967/wu.89090568478.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8975/wu.89098578354.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8985/wu.89092489152.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8986/wu.89099888760.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8987/wu.89099188872.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8988/wu.89099882482.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/wu/8990/wu.89094393303.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/yul/1110_/yul.12519116_000_00.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/yul/1140_/yul.11815542_001_00.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/yul/1330_/yul.11735935_000_00.json.bz2, skipping...
# No valid language data found in ../../Volumes/My Passport for Mac/yul/1830_/yul.12487330_000_00.json.bz2, skipping...
